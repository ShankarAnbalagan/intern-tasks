# %%
import tweepy
import json

consumer_key='rJt6u8nqeO8xCiX7ryHKE5BKy'
consumer_secret='bK60AVjZPovgczDWlMsybUkNSXGjORz2H3zRely01caH0TKxQY'

access_token='1333197186-KJnsCBsQOXWFYyPvNyjQp8WDy4oW8dZJWAWPmiM'
access_secret='NNrAOTtolULwydXcxG71OIObmeqXjsBBhHG8WMgNO46H6'

auth=tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token, access_secret)

twt_api=tweepy.API(auth)

tweets = twt_api.user_timeline(id='ShwethaMurali98', count=100)

tweets_file=open('tweet_data.txt','w')
for tweet in tweets:
    tweets_file.write(json.dumps(tweet._json))

tweets_file.close()

# %%
tweets_file=open('tweet_data.txt','r')
tweets=tweets_file.read()

print(tweets)
print(tweets[2320])
#tweets=json.loads()
# Out:
# {"created_at": "Sun Jun 02 15:22:57 +0000 2019", "id": 1135205164669816832, "id_str": "1135205164669816832", "text": "@stoic_swap Facts", "truncated": false, "entities": {"hashtags": [], "symbols": [], "user_mentions": [{"screen_name": "stoic_swap", "name": "Swapnil Kumar", "id": 1165225812, "id_str": "1165225812", "indices": [0, 11]}], "urls": []}, "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>", "in_reply_to_status_id": 1135202334835789826, "in_reply_to_status_id_str": "1135202334835789826", "in_reply_to_user_id": 1165225812, "in_reply_to_user_id_str": "1165225812", "in_reply_to_screen_name": "stoic_swap", "user": {"id": 1074255250637316097, "id_str": "1074255250637316097", "name": "Shwetha Murali", "screen_name": "ShwethaMurali98", "location": "", "description": "I'm apparently scary.\nBTS stan acc- @moonchild07_", "url": null, "entities": {"description": {"urls": []}}, "protected": false, "followers_count": 26, "friends_count": 149, "listed_count": 0, "created_at": "Sun Dec 16 10:49:45 +0000 2018", "favourites_count": 1013, "utc_offset": null, "time_zone": null, "geo_enabled": false, "verified": false, "statuses_count": 164, "lang": null, "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "F5F8FA", "profile_background_image_url": null, "profile_background_image_url_https": null, "profile_background_tile": false, "profile_image_url": "http://pbs.twimg.com/profile_images/1074256113523015680/VHCltIoU_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/1074256113523015680/VHCltIoU_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/1074255250637316097/1554555990", "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "has_extended_profile": false, "default_profile": true, "default_profile_image": false, "following": true, "follow_request_sent": false, "notifications": true, "translator_type": "none"}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 0, "favorite_count": 1, "favorited": false, "retweeted": false, "lang": "en"}{"created_at": "Sun Jun 02 10:12:16 +0000 2019", "id": 1135126980259504128, "id_str": "1135126980259504128", "text": "RT @hoegenic: no one:\n\nteacher about to draw a picture on the whiteboard: okay i am not an artist", "truncated": false, "entities": {"hashtags": [], "symbols": [], "user_mentions": [{"screen_name": "hoegenic", "name": "b", "id": 719741316515676160, "id_str": "719741316515676160", "indices": [3, 12]}], "urls": []}, "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 1074255250637316097, "id_str": "1074255250637316097", "name": "Shwetha Murali", "screen_name": "ShwethaMurali98", "location": "", "description": "I'm apparently scary.\nBTS stan acc- @moonchild07_", "url": null, "entities": {"description": {"urls": []}}, "protected": false, "followers_count": 26, "friends_count": 149, "listed_count": 0, "created_at": "Sun Dec 16 10:49:45 +0000 2018", "favourites_count": 1013, "utc_offset": null, "time_zone": null, "geo_enabled": false, "verified": false, "statuses_count": 164, "lang": null, "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "F5F8FA", "profile_background_image_url": null, "profile_background_image_url_https": null, "profile_background_tile": false, "profile_image_url": "http://pbs.twimg.com/profile_images/1074256113523015680/VHCltIoU_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/1074256113523015680/VHCltIoU_ ...
# {

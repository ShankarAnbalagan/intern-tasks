# %%
import tweepy
import json

consumer_key='rJt6u8nqeO8xCiX7ryHKE5BKy'
consumer_secret='bK60AVjZPovgczDWlMsybUkNSXGjORz2H3zRely01caH0TKxQY'

access_token='1333197186-KJnsCBsQOXWFYyPvNyjQp8WDy4oW8dZJWAWPmiM'
access_secret='NNrAOTtolULwydXcxG71OIObmeqXjsBBhHG8WMgNO46H6'

auth=tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token, access_secret)

twt_api=tweepy.API(auth)

tweets = twt_api.user_timeline(id='ShwethaMurali98', count=20)

tweets_file=open('tweet_data.txt','w')
for tweet in tweets:
    tweets_file.write(json.dumps(tweet._json)+'\n')
tweets_file.close()

# %%
tweets_file=open('tweet_data.txt','r')
for tweet in tweets_file:
    twt_json=json.loads(tweet)
    print('Tweet id: '+twt_json['id_str'])
    print(twt_json['text'])
    print('----------------------------------------------------------------------------------------')
# Out:
# Tweet id: 1135205164669816832
# @stoic_swap Facts
# ----------------------------------------------------------------------------------------
# Tweet id: 1135126980259504128
# RT @hoegenic: no one:
#
# teacher about to draw a picture on the whiteboard: okay i am not an artist
# ----------------------------------------------------------------------------------------
# Tweet id: 1135124925490974721
# Me: I'll have to study for my upcoming exams
# 8 year old nephew: Lol sad life
# ----------------------------------------------------------------------------------------
# Tweet id: 1135073139178631168
# RT @taIIant: Me: *accidentally long presses on an app*
#
# My other apps: https://t.co/O2DbVnuu2c
# ----------------------------------------------------------------------------------------
# Tweet id: 1135072347319222272
# Nothing is more irritating than a mosquito bite on your feet
# ----------------------------------------------------------------------------------------
# ...
